# %%
from sj_parcer import sj_parcer

# %%
df = sj_parcer('c#')
# Out:
# Conneting to page https://www.superjob.ru/vacancy/search/?keywords=c%23
# Conneting to page https://www.superjob.ru/vacancy/search/?keywords=c%23&page=2

# %%
len(df)
# Out:
# 23

# %%
df
# Out:
#                                               vacancy  min_salary  max_salary  \
# 0                        Программист Visual Basic.Net    100000.0         NaN
# 1   Инженер, старший инженер (отдел аппаратно-прог...     45000.0     55000.0
# 2                                     Программист С++     80000.0         NaN
# 3   Программист C# (для разработки систем АИИС КУЭ...         NaN    150000.0
# 4                                      Программист C#    100000.0         NaN
# 5                           Senior C# /.NET developer         NaN         NaN
# 6                        Ведущий разработчик C#, .NET    140000.0    160000.0
# 7                                      Программист C#         NaN    120000.0
# 8                                      Программист C#         NaN    150000.0
# 9                    Ведущий инженер-программист (С#)    100000.0         NaN
# 10                               Инженер по внедрению     49700.0     56500.0
# ...

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-23%20%D0%B2%2021.50.19.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-10-23%20%D0%B2%2021.50.19.png)
